# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets
from torch.utils.data import DataLoader

# %%
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")
    
print("Using PyTorch verison : ", torch.__version__, 'Device: ', DEVICE)
# Out:
# Using PyTorch verison :  1.13.1+cpu Device:  cpu

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
train_dataset = datasets.MNIST(root = '../data/MNIST', train = True, download = True, transform = transforms.ToTensor())
test_dataset = datasets.MNIST(root = '../data/MNIST', train = False, transform = transforms.ToTensor())
train_loader = DataLoader(dataset = train_dataset, batch_size = BATCH_SIZE, shuffle = True)
test_loader = DataLoader(dataset = test_dataset, batch_size = BATCH_SIZE, shuffle = False)

# %%
for (X_train, y_train) in train_loader:
    print("X_train : ", X_train.size(), 'type :', X_train.type())
    print("y_train : ", y_train.size(), 'type :', y_train.type())
    break
    
## 32개의 이미지 데이터가 1개의 minibatch로 구성되어 있고, 그림은 28 x 28 로 구성되어 있음
# Out:
# X_train :  torch.Size([32, 1, 28, 28]) type : torch.FloatTensor
# y_train :  torch.Size([32]) type : torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize = (10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.axis("off")
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28,28), cmap = 'gray_r')
    plt.title("class : " + str(y_train[i].item()))

# %%
class Net(nn.Module):
    def __init__(self): #내가 사용할 layer 정의
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)
        self.fc2 = nn.Linear(512 , 256)
        self.fc3 = nn.Linear(256, 10)
        self.dropout_prob = 0.5
    def forward(self, x): # 내가 넣을 데이터는 x로 잡고 모델 구성시작.
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.relu(x)
        x = F.dropout(x, training = self.training, p = self.dropout_prob)
        x = self.fc2(x)
        x = F.relu(x)
        x = F.dropout(x, training = self.training, p = self.dropout_prob)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
import torch.nn.init as init

def weight_init(m):
    if isinstance(m, nn.Linear):
        init.kaiming_uniform_(m.weight.data)
        
    

model = Net().to(DEVICE)
model.apply(weight_init) # HE init
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
def train(model, train_loader ,optimizer, log_interval):
    model.train() # train 상태로 규정
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print("Train Epoch : {} [{}/{} ({:.0f}%)] \t Train Loss : {:.6f}".format(Epoch, batch_idx * len(image), len(train_loader.dataset),
                 100. * batch_idx / len(train_loader), loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval() # 평가 상태로 규정
    test_loss = 0
    correct = 0
    
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
            
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for Epoch in range(1, EPOCHS + 1):
    train(model, train_loader ,optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n [EPOCH: {}], \t Test Loss : {:.4f}, \t Test Accuracy : {:.2f} %\n".format(Epoch, test_loss, test_accuracy))
# Out:
# Train Epoch : 1 [0/60000 (0%)] 	 Train Loss : 2.742333
# Train Epoch : 1 [6400/60000 (11%)] 	 Train Loss : 0.995327
# Train Epoch : 1 [12800/60000 (21%)] 	 Train Loss : 1.000553
# Train Epoch : 1 [19200/60000 (32%)] 	 Train Loss : 0.348600
# Train Epoch : 1 [25600/60000 (43%)] 	 Train Loss : 0.499227
# Train Epoch : 1 [32000/60000 (53%)] 	 Train Loss : 0.443328
# Train Epoch : 1 [38400/60000 (64%)] 	 Train Loss : 0.405868
# Train Epoch : 1 [44800/60000 (75%)] 	 Train Loss : 0.407456
# Train Epoch : 1 [51200/60000 (85%)] 	 Train Loss : 0.457220
# Train Epoch : 1 [57600/60000 (96%)] 	 Train Loss : 0.334979
#
#  [EPOCH: 1], 	 Test Loss : 0.0081, 	 Test Accuracy : 92.38 %
#
# Train Epoch : 2 [0/60000 (0%)] 	 Train Loss : 0.392433
# Train Epoch : 2 [6400/60000 (11%)] 	 Train Loss : 0.211162
# Train Epoch : 2 [12800/60000 (21%)] 	 Train Loss : 0.280027
# Train Epoch : 2 [19200/60000 (32%)] 	 Train Loss : 0.620903
# Train Epoch : 2 [25600/60000 (43%)] 	 Train Loss : 0.205547
# Train Epoch : 2 [32000/60000 (53%)] 	 Train Loss : 0.248922
# Train Epoch : 2 [38400/60000 (64%)] 	 Train Loss : 0.223083
# Train Epoch : 2 [44800/60000 (75%)] 	 Train Loss : 0.238256
# Train Epoch : 2 [51200/60000 (85%)] 	 Train Loss : 0.141987
# Train Epoch : 2 [57600/60000 (96%)] 	 Train Loss : 0.202009
#
#  [EPOCH: 2], 	 Test Loss : 0.0059, 	 Test Accuracy : 94.21 %
#
# Train Epoch : 3 [0/60000 (0%)] 	 Train Loss : 0.232790
# Train Epoch : 3 [6400/60000 (11%)] 	 Train Loss : 0.331828
# Train Epoch : 3 [12800/60000 (21%)] 	 Train Loss : 0.178733
# Train Epoch : 3 [19200/60000 (32%)] 	 Train Loss : 0.208746
# Train Epoch : 3 [25600/60000 (43%)] 	 Train Loss : 0.254118
# Train Epoch : 3 [32000/60000 (53%)] 	 Train Loss : 0.411350
# Train Epoch : 3 [38400/60000 (64%)] 	 Train Loss : 0.182159
# Train Epoch : 3 [44800/60000 (75%)] 	 Train Loss : 0.277740
# Train Epoch : 3 [51200/60000 (85%)] 	 Train Loss : 0.164685
# Train Epoch : 3 [57600/60000 (96%)] 	 Train Loss : 0.215310
#
#  [EPOCH: 3], 	 Test Loss : 0.0048, 	 Test Accuracy : 95.31 %
#
# Train Epoch : 4 [0/60000 (0%)] 	 Train Loss : 0.332505
# Train Epoch : 4 [6400/60000 (11%)] 	 Train Loss : 0.265582
# Train Epoch : 4 [12800/60000 (21%)] 	 Train Loss : 0.145860
# Train Epoch : 4 [19200/60000 (32%)] 	 Train Loss : 0.105495
# Train Epoch : 4 [25600/60000 (43%)] 	 Train Loss : 0.226256
# Train Epoch : 4 [32000/60000 (53%)] 	 Train Loss : 0.172341
# Train Epoch : 4 [38400/60000 (64%)] 	 Train Loss : 0.032096
# Train Epoch : 4 [44800/60000 (75%)] 	 Train Loss : 0.350896
# Train Epoch : 4 [51200/60000 (85%)] 	 Train Loss : 0.097976
# Train Epoch : 4 [57600/60000 (96%)] 	 Train Loss : 0.282340
#
#  [EPOCH: 4], 	 Test Loss : 0.0042, 	 Test Accuracy : 95.94 %
#
# Train Epoch : 5 [0/60000 (0%)] 	 Train Loss : 0.274254
# Train Epoch : 5 [6400/60000 (11%)] 	 Train Loss : 0.201307
# Train Epoch : 5 [12800/60000 (21%)] 	 Train Loss : 0.155002
# Train Epoch : 5 [19200/60000 (32%)] 	 Train Loss : 0.087223
# Train Epoch : 5 [25600/60000 (43%)] 	 Train Loss : 0.204434
# Train Epoch : 5 [32000/60000 (53%)] 	 Train Loss : 0.072219
# Train Epoch : 5 [38400/60000 (64%)] 	 Train Loss : 0.265576
# Train Epoch : 5 [44800/60000 (75%)] 	 Train Loss : 0.159235
# Train Epoch : 5 [51200/60000 (85%)] 	 Train Loss : 0.157828
# Train Epoch : 5 [57600/60000 (96%)] 	 Train Loss : 0.361072
#
#  [EPOCH: 5], 	 Test Loss : 0.0037, 	 Test Accuracy : 96.35 %
#
# Train Epoch : 6 [0/60000 (0%)] 	 Train Loss : 0.090237
# Train Epoch : 6 [6400/60000 (11%)] 	 Train Loss : 0.278442
# Train Epoch : 6 [12800/60000 (21%)] 	 Train Loss : 0.065952
# Train Epoch : 6 [19200/60000 (32%)] 	 Train Loss : 0.124241
# Train Epoch : 6 [25600/60000 (43%)] 	 Train Loss : 0.140114
# Train Epoch : 6 [32000/60000 (53%)] 	 Train Loss : 0.300231
# Train Epoch : 6 [38400/60000 (64%)] 	 Train Loss : 0.075805
# Train Epoch : 6 [44800/60000 (75%)] 	 Train Loss : 0.285619
# Train Epoch : 6 [51200/60000 (85%)] 	 Train Loss : 0.330824
# Train Epoch : 6 [57600/60000 (96%)] 	 Train Loss : 0.302836
#
#  [EPOCH: 6], 	 Test Loss : 0.0034, 	 Test Accuracy : 96.60 %
#
# Train Epoch : 7 [0/60000 (0%)] 	 Train Loss : 0.209686
# Train Epoch : 7 [6400/60000 (11%)] 	 Train Loss : 0.287758
# Train Epoch : 7 [12800/60000 (21%)] 	 Train Loss : 0.123691
# Train Epoch : 7 [19200/60000 (32%)] 	 Train Loss : 0.032424
# Train Epoch : 7 [25600/60000 (43%)] 	 Train Loss : 0.193335
# Train Epoch : 7 [32000/60000 (53%)] 	 Train Loss : 0.123867
# Train Epoch : 7 [38400/60000 (64%)] 	 Train Loss : 0.123137
# Train Epoch : 7 [44800/60000 (75%)] 	 Train Loss : 0.296717
# Train Epoch : 7 [51200/60000 (85%)] 	 Train Loss : 0.373225
# Train Epoch : 7 [57600/60000 (96%)] 	 Train Loss : 0.080799
#
#  [EPOCH: 7], 	 Test Loss : 0.0032, 	 Test Accuracy : 96.92 %
#
# Train Epoch : 8 [0/60000 (0%)] 	 Train Loss : 0.129118
# Train Epoch : 8 [6400/60000 (11%)] 	 Train Loss : 0.079396
# Train Epoch : 8 [12800/60000 (21%)] 	 Train Loss : 0.101987
# Train Epoch : 8 [19200/60000 (32%)] 	 Train Loss : 0.233564
# Train Epoch : 8 [25600/60000 (43%)] 	 Train Loss : 0.082868
# Train Epoch : 8 [32000/60000 (53%)] 	 Train Loss : 0.121154
# Train Epoch : 8 [38400/60000 (64%)] 	 Train Loss : 0.294082
# Train Epoch : 8 [44800/60000 (75%)] 	 Train Loss : 0.130202
# Train Epoch : 8 [51200/60000 (85%)] 	 Train Loss : 0.039804
# Train Epoch : 8 [57600/60000 (96%)] 	 Train Loss : 0.198774
#
#  [EPOCH: 8], 	 Test Loss : 0.0030, 	 Test Accuracy : 97.00 %
#
# Train Epoch : 9 [0/60000 (0%)] 	 Train Loss : 0.058613
# Train Epoch : 9 [6400/60000 (11%)] 	 Train Loss : 0.071464
# Train Epoch : 9 [12800/60000 (21%)] 	 Train Loss : 0.281101
# Train Epoch : 9 [19200/60000 (32%)] 	 Train Loss : 0.094853
# Train Epoch : 9 [25600/60000 (43%)] 	 Train Loss : 0.158045
# Train Epoch : 9 [32000/60000 (53%)] 	 Train Loss : 0.140576
# Train Epoch : 9 [38400/60000 (64%)] 	 Train Loss : 0.166051
# Train Epoch : 9 [44800/60000 (75%)] 	 Train Loss : 0.100355
# Train Epoch : 9 [51200/60000 (85%)] 	 Train Loss : 0.190336
# Train Epoch : 9 [57600/60000 (96%)] 	 Train Loss : 0.276918
#
#  [EPOCH: 9], 	 Test Loss : 0.0029, 	 Test Accuracy : 97.17 %
#
# Train Epoch : 10 [0/60000 (0%)] 	 Train Loss : 0.459487
# Train Epoch : 10 [6400/60000 (11%)] 	 Train Loss : 0.195108
# Train Epoch : 10 [12800/60000 (21%)] 	 Train Loss : 0.353592
# Train Epoch : 10 [19200/60000 (32%)] 	 Train Loss : 0.119626
# Train Epoch : 10 [25600/60000 (43%)] 	 Train Loss : 0.445616
# Train Epoch : 10 [32000/60000 (53%)] 	 Train Loss : 0.254214
# Train Epoch : 10 [38400/60000 (64%)] 	 Train Loss : 0.106596
# Train Epoch : 10 [44800/60000 (75%)] 	 Train Loss : 0.088806
# Train Epoch : 10 [51200/60000 (85%)] 	 Train Loss : 0.043151
# Train Epoch : 10 [57600/60000 (96%)] 	 Train Loss : 0.090803
#
#  [EPOCH: 10], 	 Test Loss : 0.0028, 	 Test Accuracy : 97.17 %
